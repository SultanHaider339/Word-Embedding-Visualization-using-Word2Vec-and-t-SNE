# %% [markdown]
# # Importing Library

# %%
import pandas as pd
import re
import nltk
from nltk.tokenize import word_tokenize
from gensim.models import Word2Vec
from sklearn.manifold import TSNE
import numpy as np
import plotly.express as px

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# # Loading Dataset

# %%
# Read the text file into a DataFrame
with open('/content/Assignmentdataset.txt', 'r', encoding='utf-8') as file:
    content = file.read()

# Split the content into individual sentences
sentences = content.split('.')

# Create a DataFrame
df = pd.DataFrame(sentences, columns=['text'])

# Strip any leading/trailing whitespace
df['text'] = df['text'].str.strip()

# %% [markdown]
# # Word Embedding

# %%
# Function to preprocess the text
def preprocess_text(text):
    # Remove non-alphanumeric characters and tokenize
    text = re.sub(r'\W+', ' ', text)
    text = re.sub(r'\d+', '', text)  # Remove numbers
    return word_tokenize(text.lower())

# Function to filter out text with numeric data
def remove_numeric(text):
    # Check if the text contains any numeric characters
    return not any(char.isdigit() for char in text)

# Remove rows with numeric data
df['text'] = df['text'].apply(lambda x: x if remove_numeric(x) else '')

# Preprocess the entire dataset (exclude empty strings)
processed_texts = [preprocess_text(text) for text in df['text'] if text]

# Train Word2Vec model
model = Word2Vec(sentences=processed_texts, vector_size=100, window=5, min_count=1, workers=4)

# Prepare data for visualization
words = list(model.wv.index_to_key)
embeddings = np.array([model.wv[word] for word in words])

# Use t-SNE to reduce dimensions (3D)
tsne = TSNE(n_components=3, random_state=0)
embeddings_3d = tsne.fit_transform(embeddings)

# Create a DataFrame for Plotly
embedding_df = pd.DataFrame(embeddings_3d, columns=['x', 'y', 'z'])
embedding_df['word'] = words

# %% [markdown]
# # Ploting The Graph

# %%
# Create an interactive 3D scatter plot using Plotly
fig = px.scatter_3d(embedding_df, x='x', y='y', z='z', text='word', title='Word Embeddings')
fig.update_traces(textposition='top center')
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ef4efc60-cda4-4058-bc54-ad7eb98f0787" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef4efc60-cda4-4058-bc54-ad7eb98f0787")) {                    Plotly.newPlot(                        "ef4efc60-cda4-4058-bc54-ad7eb98f0787",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ez=%{z}\u003cbr\u003eword=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","scene":"scene","showlegend":false,"text":["ki","ke","hai","mein","se","to","ka","ko","aur","bhi","hain","ne","nahi","is","aap","par","kar","hi","ho","kya","woh","aik","hon","bohat","liye","nah","tha","hum","ab","kuch","jo","baat","mujhe","nazar","bhai","un","ga","phir","allah","o","sab","kisi","raha","sahib","jee","ya","sun","apne","rahay","dil","lekin","meri","agar","jaye","hwa","gaya","ge","jab","karne","yahan","sath","they","jis","taq","rahi","har","tum","aaj","pay","diya","hota","urdu","di","kyun","karen","baad","na","gi","be","kaam","abhi","day","pehlay","kabhi","acha","ja","do","magar","naam","baghaawat","terhan","kaha","hue","pakistan","mera","gaye","walay","dehli","bhiya","khud","gayi","waqt","aisa","ziyada","din","aa","usay","log","janab","mehfhil","si","mamu","kis","khayaal","waisay","karna","hoti","yaad","le","isi","hui","ik","saal","khoob","taraf","khush","kam","sirf","jawab","mubarak","pata","achi","den","kahin","aeye","mujh","kahan","karta","shayad","yahi","ghazal","ban","dekh","chahiye","aaya","apna","kaisay","he","samajh","hamein","kon","honay","theek","jata","aisay","wala","logon","sakta","yeh","aayi","sa","haan","zindagi","jaan","ae","baar","shamshad","mil","hoga","salam","hotay","hamaray","bana","kere","jaane","lagta","kal","len","jaisay","likha","mohammad","wali","paas","jayen","jahan","wah","sipahi","al","tamam","keh","zara","baray","bilkul","pasand","kaafi","mohabbat","baqi","kkhuda","naan","yun","ahmed","liya","shair","aisi","kehte","wohi","dono","tig","tehreer","hamari","jin","dekha","atay","wajah","pi","shayar","mazeed","satke","shuru","itna","jati","yani","raat","e","karachi","wahan","itni","rakha","barri","lag","barray","sawal","batain","haal","ilm","aati","koshish","kitaab","az","hazrat","malik","khabar","maloom","reh","balkay","kher","ali","paish","aleh","shairi","behtar","soch","kab","zaroor","islam","karti","hona","anay","dosray","khan","dua","inhen","walon","umeed","jagah","khusi","aamdeed","warna","umar","karo","ensaan","tor","dost","lau","samnay","mohtaram","teen","dete","bta","blog","mushkil","deta","shehar","pakistani","dainay","bayan","der","ghair","khobsorat","parh","jana","rahen","istemaal","sakti","kyunkay","aankhon","mojood","lagey","durust","tasweer","khawab","ghalat","bara","achay","haq","likh","parre","zaroorat","cheez","mila","agay","aqwami","ameeen","umdah","pehli","matlab","jari","marey","amal","ishhq","chal","peda","kayi","aam","saaray","unhon","bi","roz","shakhs","lafz","hogi","masla","am","mout","zabardast","chand","dun","husn","poori","subah","gham","test","miley","pehla","khatam","teri","kiye","dekhen","deen","shadi","mukammal","dr","quran","hamara","chore","shaam","zabaan","arrey","alaikum","naye","kehna","tre","kalaam","nai","sale","sahih","bhar","yaqeen","pani","chaar","koi","letay","haasil","intzaar","rang","sach","khaas","chalay","bananay","itnay","farmaya","sara","theen","band","li","aakhri","aakhir","dar","abbu","daal","chaye","andaaz","nazam","soorat","website","yaar","aawaz","doosri","asal","shah","kaar","hukoomat","izhaar","saari","hamesha","dena","jald","link","naya","lagi","imran","qisam","america","wasallam","bhae","tv","maza","rehta","wapas","aks","bachay","iqbal","tab","m","kha","nik ...
